# %%
class Maillon:
    def __init__(self, element, suivant=None):
        assert suivant is None or isinstance(suivant, Maillon)
        
        self.element = element
        self.suivant = suivant
        

    def longueur(chaine):
        """Renvoie la longueur d'une chaîne (le nombre de maillons) """
        
        actuel = chaine
        compteur = 0
        while actuel.suivant is not None:
            compteur += 1
            actuel = actuel.suivant
            return compteur
    

    def affiche(chaine):
        """Affiche tous les éléments de la chaine"""
        
        actuel = chaine
        ma_chaine += "{"
        for _ in range(longueur(chaine)):
            ma chaine += str(actuel.element), end='')
            if actuel.suivant is not None:
                ma_chaine += ', '
                actuel = actuel.suivant
                ma_chaine += "}"
                print(ma_chaine)
        
        
    def affiche2(chaine, (ccar='{', c=longueur(chaine))):
        if c == 0:
            
        if chaine.suivant is not None:
            affiche2(chaine.suivant, ccar + str(chaine.element), c - 1)
            


une_chaine = Maillon(1)
une_chaine.suivant = Maillon(2)
une_chaine = Maillon(1, Maillon(2, Maillon(3)))
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
#   File "<input>", line 34, in Maillon
#   File "<input>", line 27, in affiche
# NameError: name 'longueur' is not defined
# {
